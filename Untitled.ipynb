# %%
import pandas as pd

# %%
df = pd.read_csv('Data/survey_results_public.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
# set the index for the dataFrame

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['YearsCode','QuestionText']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.index # return all value of the 0 coulmn
# Out:
# Index(['Age', 'Age1stCode', 'CompFreq', 'CompTotal', 'ConvertedComp',
#        'Country', 'CurrencyDesc', 'CurrencySymbol', 'DatabaseDesireNextYear',
#        'DatabaseWorkedWith', 'DevType', 'EdLevel', 'Employment', 'Ethnicity',
#        'Gender', 'Hobbyist', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith', 'MainBranch',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Respondent', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'Sexuality', 'SurveyEase',
# ...

# %%
df.drop({'Trans'},axis=1, inplace=True)

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4754
# Information systems, information technology, or system administration              4071
# A natural science (such as biology, chemistry, physics, etc.)                      2205
# Mathematics or statistics                                                          1849
# Web development or web design                                                      1789
# A business discipline (such as accounting, finance, marketing, etc.)               1375
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# I never declared a major                                                            453
# ...

# %%
df.rename(columns={'ConvertedComp':'Salary'},inplace=True)

# %%
filt = df['UndergradMajor'] == 'Mathematics or statistics'
df.loc[filt,['Age','Salary']]
# Out:
#         Age     Salary
# 9      22.0    32315.0
# 11     49.0    14268.0
# 54      NaN        NaN
# 71     25.0        NaN
# 129    37.0   115000.0
# 150    30.0   121980.0
# 200    22.0        NaN
# 206    40.0    27240.0
# 269    22.0    85000.0
# 279    26.0  1104000.0
# 347    27.0   130000.0
# 401    34.0   105000.0
# 420    45.0   117229.0
# 434    24.0    75000.0
# 475    28.0    46533.0
# 506     NaN   250000.0
# 517     NaN        NaN
# 575    53.0   112500.0
# 583    30.0   120000.0
# 640    71.0        NaN
# 658    32.0        NaN
# 681     NaN        NaN
# 708    29.0   120000.0
# 750    20.0        NaN
# 773    35.0    38915.0
# 787    32.0    70000.0
# 807    28.0    74000.0
# 828    25.0        NaN
# 879    59.0        NaN
# 900    47.0  1000000.0
# 912    33.0     5652.0
# 938    55.0        NaN
# 1002   31.0   200000.0
# 1014   52.0    33024.0
# 1076    NaN        NaN
# 1100   28.0        NaN
# 1103   30.0     1592.0
# 1115   51.0    83236.0
# 1122   27.0    30000.0
# ...

# %%
# Salary for diffrent major ( Math / Scince ):
# import matplotlib.
# / x = number of observation 
# / y = Salary
import matplotlib.pyplot as plt
x = df['UndergradMajor'] == 'Computer science, computer engineering, or software engineering'

# %%
df2 = df.loc[x,['Respondent','Salary']]

# %%
df2 = df2.dropna()

# %%
df.UndergradMajor.value_counts().head(4)
# Out:
# Computer science, computer engineering, or software engineering                 31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)     4754
# Information systems, information technology, or system administration            4071
# A natural science (such as biology, chemistry, physics, etc.)                    2205
# Name: UndergradMajor, dtype: int64

# %%
df.UndergradMajor.value_counts().head(3).plot(kind='bar',figsize=(12,12))
plt.xticks(rotation=0);  # Quick plot by category

# %%
df["Age"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
# 5         NaN
# 6         NaN
# 7        36.0
# 8        30.0
# 9        22.0
# 10       23.0
# 11       49.0
# 12       53.0
# 13       27.0
# 14        NaN
# 15       45.0
# 16       25.0
# 17       32.0
# 18       24.0
# 19       40.0
# 20       23.0
# 21        NaN
# 22       27.0
# 23       45.0
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28       18.0
# 29        NaN
# 30        NaN
# 31       31.0
# 32       39.0
# 33       29.0
# 34       16.0
# 35       34.0
# 36       19.0
# 37       35.0
# 38        NaN
# 39       20.0
# 40        NaN
# 41       32.0
#          ...
# 64419     NaN
# 64420    22.0
# 64421    17.0
# 64422    23.0
# 64423     NaN
# 64424     NaN
# 64425     NaN
# 64426    22.0
# 64427    34.0
# 64428     NaN
# 64429     NaN
# 64430    38.0
# 64431     NaN
# 64432     NaN
# 64433    64.0
# 64434     NaN
# 64435     NaN
# 64436     NaN
# 64437     NaN
# ...

# %%
df.Age.value_counts().head()
# Out:
# 25.0    2693
# 28.0    2412
# 30.0    2406
# 26.0    2391
# 27.0    2338
# Name: Age, dtype: int64

# %%
df.plot(x='Salary',y='MapedUndergradMajor',kind='scatter', figsize=(12,12));     # Bigger plot by increasing age
plt.xlabel('Salary');
plt.ylabel('UndergradMajor');
plt.title('Number of users per age');

# %%
df.UndergradMajor.value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4754
# Information systems, information technology, or system administration              4071
# A natural science (such as biology, chemistry, physics, etc.)                      2205
# Mathematics or statistics                                                          1849
# Web development or web design                                                      1789
# A business discipline (such as accounting, finance, marketing, etc.)               1375
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# I never declared a major                                                            453
# ...

# %%
df["MapedUndergradMajor"] = df.UndergradMajor.map(
    {
     'Computer science, computer engineering, or software engineering':0,
     'Another engineering discipline (such as civil, electrical, mechanical, etc.):':1,
     'Information systems, information technology, or system administration':2,
     'A natural science (such as biology, chemistry, physics, etc.) ':3,
     'Mathematics or statistics':4,
     'Web development or web design':5,
     'A business discipline (such as accounting, finance, marketing, etc.) ':6,
     'A humanities discipline (such as literature, history, philosophy, etc.)':7,
     'A social science (such as anthropology, psychology, political science, etc.)':8,
     'Fine arts or performing arts (such as graphic design, music, studio art, etc.)':9,
     'I never declared a major':10,
     'A health science (such as nursing, pharmacy, radiology, etc.)':10
    })

# %%
df['MapedUndergradMajor'].value_counts()
# Out:
# 0.0     31582
# 2.0      4071
# 4.0      1849
# 5.0      1789
# 7.0      1007
# 8.0       933
# 9.0       725
# 10.0      705
# Name: MapedUndergradMajor, dtype: int64

# %%
ax2 = df.plot(x="Salary", y="MapedUndergradMajor",kind='bar',figsize=(12,12))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-386-bf36de59ee12> in <module>()
# ----> 1 ax2 = df.plot(x="Salary", y="MapedUndergradMajor",kind='bar',figsize=(12,12))
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
plt.plot(df2['Salary'],df2['Respondent'])

# %%
filt = (df['Salary']>1000000) & (df['Country'].isin(['United States','Germany', 'india']))

# %%
df.loc[filt,['MainBranch','LanguageWorkedWith', 'YearsCode','Gender']].Gender.value_counts()
# Out:
# Man                                                  323
# Woman                                                 26
# Non-binary, genderqueer, or gender non-conforming      2
# Name: Gender, dtype: int64

# %%
def changeHobbyist(value):
    if value=='Yes':
        value = True
        return value
    else:
        return False

# %%
df['Hobbyist'].apply(changeHobbyist)

# %%
df['Hobbyist'].map({'Yes' : True, 'No' : False})

# %%
df['Hobbyist']
